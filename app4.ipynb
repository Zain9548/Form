# %%
import dash
from dash import dcc,html
import dash_html_components as html
# Out:
# C:\Users\ajeem\AppData\Local\Temp\ipykernel_8324\1985623152.py:3: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %%
app3=dash.Dash()

# %%
app3.layout=html.Div([
    html.H1("𝓓𝓪𝓽𝓪 𝓢𝓬𝓲𝓮𝓷𝓽𝓲𝓼𝓽",
           style={
               'textAlign':'center',
               'color':'#FF0000'
           }),
    html.H2("𝓕𝓾𝓵𝓵 𝓯𝓲𝓵𝓵 𝓓𝓻𝓮𝓪𝓶",
              style={
                  'textAlign':'center',
                   'color':'#FF0000'
                  
              }),
    html.Br(),
    html.Label("𝓦𝓱𝓪𝓽 𝓲𝓼 𝔂𝓸𝓾𝓻 𝓷𝓪𝓶𝓮? ",
              style={
                  'display': 'flex', 
                  'alignItems': 'center', 
                  'justifyContent': 'center',
                  'fontSize':'25px'
              }),
    dcc.Input(
    placeholder="input name",
        type='text',
        value=' ',
        style={'width':'98%','flex': '1', 'padding': '10px', 'border': '1px solid #ccc', 'borderRadius': '4px'}
    ),
    html.Br(),
    html.Br(),
    html.Label("𝓦𝓱𝓪𝓽 𝓲𝓼 𝔂𝓸𝓾𝓻 𝓬𝓸𝓵𝓵𝓮𝓰𝓮 ?",
                style={
                   'display': 'flex', 
                  'alignItems': 'center', 
                  'justifyContent': 'center',
                  'fontSize':'25px'
                }),
              
    dcc.Input(
    placeholder="input name",
        type='text',
        value=' ', 
        style={'width':'98%','flex': '1', 'padding': '10px', 'border': '1px solid #ccc', 'borderRadius': '4px'}
    ),
    html.Br(),
    html.Label("𝓔𝓷𝓽𝓮𝓻 𝔂𝓸𝓾𝓻 𝓔𝓶𝓪𝓲𝓵? ",
              style={
                  'display': 'flex', 
                  'alignItems': 'center', 
                  'justifyContent': 'center',
                  'fontSize':'25px'
              }),
     dcc.Input(
    placeholder="input email",
        type='text',
        value=' ', 
        style={'width':'98%','flex': '1', 'padding': '10px', 'border': '1px solid #ccc', 'borderRadius': '4px'}
    ),
    
    html.Br(),
    html.Br(),
    html.Label("𝓒𝓾𝓻𝓻𝓮𝓷𝓽 𝓔𝓭𝓾𝓬𝓪𝓽𝓲𝓸𝓷",
              style={
                   'display': 'flex', 
                  'alignItems': 'center', 
                  'justifyContent': 'center',
                  'fontSize':'25px'
              }),
    dcc.Dropdown(
    options=[
        {'label':'12th','value':'12th'},
        {'label':'Diploma','value':'Diploma'},
        {'label':'Under Gradute','value':'UG'},
        {'label':'Post Gradute','value':'PG'},
        {'label':'Other'}
    ],
        style={'flex': '1', 'padding': '10px', 'border': '1px solid #ccc', 'borderRadius': '4px'}
        
    ),
    html.Br(),
    html.Label("𝓒𝓱𝓸𝓼𝓼𝓮 𝓽𝓱𝓮 𝓬𝓸𝓾𝓻𝓼𝓮",
              style={
                   'display': 'flex', 
                  'alignItems': 'center', 
                  'justifyContent': 'center',
                  'fontSize':'25px'
              }),
    dcc.Checklist(
    options=[
        {'label':'12th','value':'12th'},
        {'label':'Diploma','value':'Diploma'},
        {'label':'B.Tech','value':'BT'},
        {'label':'M.Tech','value':'MT'},
        {'label':'Other'}
    ],
    style={'gap': '50px','textAlign':'center'},
    id='radio-items',
    inline=True
    ),
    html.Br(),
    html.Label("𝓖𝓻𝓪𝓭𝓾𝓽𝓲𝓸𝓷 𝓨𝓮𝓪𝓻",
              style={
                   'display': 'flex', 
                  'alignItems': 'center', 
                  'justifyContent': 'center',
                  'fontSize':'25px'
              }),
    html.Div(
    dcc.DatePickerRange(
    id='dt-pick-range',
    start_date='2024-01-01', 
    end_date_placeholder_text="Select the end date"
    ),style={'display': 'flex', 'justifyContent': 'center'}
        

            
     ),
    html.Br(),
    html.Label("𝓹𝓮𝓻𝓬𝓮𝓷𝓽𝓪𝓰𝓮",
               style={
                   'display': 'flex', 
                  'alignItems': 'center', 
                  'justifyContent': 'center',
                  'fontSize':'25px'
                }),
               
    dcc.Slider(
    min=60,
    max=100,
    step=5
    ),
    html.Br(),
    html.Label("𝓢𝓮𝓵𝓮𝓬𝓽 𝓽𝓱𝓮 𝓖𝓮𝓷𝓭𝓮𝓻",
              style={
                   'display': 'flex', 
                  'alignItems': 'center', 
                  'justifyContent': 'center',
                  'fontSize':'25px'
              }),
    dcc.RadioItems(
        options=[
             {'label':'Male','value':'male'},
            {'label':'Female','value':'female'},
            {'label':'others','value':'others'}
        ],
           
        style={'textAlign':'center'},
        id='radio-items',
        inline=True 
    
    ),
    html.Br(),
    html.Label("𝓐𝓫𝓸𝓾𝓽 𝓓𝓻𝓮𝓪𝓶",
              style={
                   'display': 'flex', 
                  'alignItems': 'center', 
                  'justifyContent': 'center',
                  'fontSize':'25px'
              }),
    dcc.Textarea(
    placeholder="Give your Feedback",
    value="text the value",
    style={'width':'100%','height':'200px'}
#{'height':'200px'}
    ),
    html.Div(
    html.Button('Submit', id='submit-form'),
        style={'display': 'flex', 'justifyContent': 'center', 'marginTop': '20px'}
    )
], style={'backgroundColor': '#00ffff','padding': '20px'})

# %%
app3.run_server(port=8054)
# Out:
# [2025-01-13 07:17:25,263] ERROR in app: Exception on /_alive_a5052381-1aa1-4a59-8da1-9b9a22eaeb06 [GET]
# Traceback (most recent call last):
#   File "c:\Users\ajeem\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1473, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\ajeem\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 882, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\ajeem\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 878, in full_dispatch_request
#     rv = self.preprocess_request()
#   File "c:\Users\ajeem\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py", line 1253, in preprocess_request
#     rv = self.ensure_sync(before_func)()
#   File "c:\Users\ajeem\AppData\Local\Programs\Python\Python310\lib\site-packages\dash\dash.py", line 1411, in _setup_server
# ...
